# %%
# 호스트에서 실행
git clone -b ros2 https://github.com/robby-404canfind/system2_bringup.git ~/hunavsim_containers/webots/hunav_webots_ws/src/system2_bringup

# %%
from openai import OpenAI

# Ollama (Edge LLM) — base_url만 다름
# client_local = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# OpenRouter (Cloud LLM) — base_url만 다름
# client_cloud = OpenAI(base_url="https://openrouter.ai/api/v1", api_key="sk-or-...")

# %%
# ollama serve &
