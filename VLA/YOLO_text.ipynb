# %%
# YOLO : You Only Look Once
# 이미지를 텍스트로 반환 bounding box, class
# 자원이 풍부할 땐 멀티모달 LLM 가 더 유리할 수 있음
# 자원이 한정적일땐 YOLO
# !pip install ultralytics

# 파이토치 필요
# !pip install -U langchain-community langchain langchain_openai langchain_core
# Out:
# Requirement already satisfied: ultralytics in C:\Python312\Lib\site-packages (8.4.21)
# Requirement already satisfied: numpy>=1.23.0 in C:\Python312\Lib\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: matplotlib>=3.3.0 in C:\Python312\Lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in C:\Python312\Lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in C:\Python312\Lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Python312\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Python312\Lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in C:\Python312\Lib\site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in C:\Python312\Lib\site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Python312\Lib\site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\sungjong.son\AppData\Roaming\Python\Python312\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars>=0.20.0 in C:\Python312\Lib\site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in C:\Python312\Lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=3 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Python312\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in C:\Python312\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: six>=1.5 in C:\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Python312\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Python312\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Python312\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Python312\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: setuptools in C:\Python312\Lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Python312\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Python312\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: langchain-community in C:\Python312\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain in C:\Python312\Lib\site-packages (1.2.12)
# Requirement already satisfied: langchain_openai in C:\Python312\Lib\site-packages (1.1.11)
# Requirement already satisfied: langchain_core in C:\Python312\Lib\site-packages (1.2.18)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Python312\Lib\site-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Python312\Lib\site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Python312\Lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in C:\Python312\Lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Python312\Lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Python312\Lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Python312\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Python312\Lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in C:\Python312\Lib\site-packages (from langchain-community) (0.7.16)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Python312\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in C:\Python312\Lib\site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Python312\Lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in C:\Python312\Lib\site-packages (from langchain_core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Python312\Lib\site-packages (from langchain_core) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Python312\Lib\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Python312\Lib\site-packages (from langchain_core) (0.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Python312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Python312\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Python312\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Python312\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in C:\Python312\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in C:\Python312\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in C:\Python312\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Python312\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in C:\Python312\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Python312\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Python312\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Python312\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Python312\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Python312\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Python312\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in C:\Python312\Lib\site-packages (from langchain) (1.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Python312\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in C:\Python312\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Python312\Lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Python312\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in C:\Python312\Lib\site-packages (from langchain_openai) (2.26.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Python312\Lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Python312\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Python312\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.13.0)
# Requirement already satisfied: sniffio in C:\Python312\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Python312\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in C:\Python312\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.2.28)
# Requirement already satisfied: colorama in C:\Python312\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain_openai) (0.4.6)

# %%
import yaml
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from ultralytics import YOLO
import cv2, json
from IPython.display import display
from PIL import Image
import warnings
import dotenv

dotenv.load_dotenv()
warnings.filterwarnings("ignore")

# %%
img_path = "./apple_ex.jpg"
frame = cv2.imread(img_path)
if frame is None:
    raise FileNotFoundError(f"이미지를 찾을 수 없습니다: {img_path}")

frame = cv2.resize(frame, (1200, 800))
results = YOLO("./yolo11n.pt")(source=frame, conf=0.5, verbose=False)

# %%
display(Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800>

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]],
#
#         [[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]],
#
#         [[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]],
#
#         ...,
#
#         [[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]],
#
#         [[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]],
#
#         [[ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          ...,
#          [ 71, 109, 211],
#          [ 71, 109, 211],
#          [ 71, 109, 211]]], shape=(800, 1200, 3), dtype=uint8)
#  orig_shape: (800, 1200)
#  path: 'image0.jpg'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 58.78579999989597, 'inference': 81.81710000008025, 'postprocess': 1.340299999810668}]

# %%
with open("./yolo_prompt2.yaml", "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)
template_str = cfg["template"]

# %%
llm = ChatOpenAI(model="gpt-4.1-nano", temperature=0.0)
prompt = PromptTemplate.from_template(template_str)
chain = (
    {"info": RunnablePassthrough(), "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
info = {}
annot = frame.copy()
for res in results:
    for b in res.boxes:
        cls = int(b.cls[0].item())
        label = res.names.get(cls, str(cls))
        x1, y1, x2, y2 = map(int, b.xyxy[0])
        x, y, w, h = map(int, b.xywh[0])
        conf = round(b.conf[0].item(), 2)
        obj = {
            "location": [x,y],
            "size": w*h,
            "bbox": [x1, y1, x2, y2],
            "confidence": conf
        }
        info.setdefault(label, []).append(obj)
        cv2.rectangle(annot, (x1,y1), (x2,y2), (0,255,0), 2)
        cv2.putText(annot, f"{label} {conf}", (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

# %%
rgb = cv2.cvtColor(annot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800>

# %%
info_str = json.dumps(info, ensure_ascii=False, indent=2)
print("info:", info_str)
# Out:
# info: {
#   "apple": [
#     {
#       "location": [
#         908,
#         425
#       ],
#       "size": 11716,
#       "bbox": [
#         850,
#         374,
#         967,
#         476
#       ],
#       "confidence": 0.93
#     },
#     {
#       "location": [
#         321,
#         483
#       ],
#       "size": 12099,
#       "bbox": [
#         265,
#         428,
#         377,
#         537
#       ],
#       "confidence": 0.87
#     }
#   ],
#   "person": [
#     {
#       "location": [
#         621,
#         446
#       ],
#       "size": 509507,
#       "bbox": [
#         255,
#         97,
#         987,
#         795
#       ],
#       "confidence": 0.91
#     }
#   ]
# }

# %%
question = "지금 보이는 물체들을 간단히 설명해줘"
answer = chain.invoke({"info": info_str, "question": question})
print("답변:", answer)
# Out:
# 답변: 지금 보이는 물체들은 사과 두 개와 사람 한 명입니다.

# %%
question = "지금 보이는 사과는 몇개야?"
answer = chain.invoke({"info": info_str, "question": question})
print("답변:", answer)
# Out:
# 답변: 지금 보이는 사과는 두 개입니다.

# %%
question = "지금 보이는 사과는 각각 어디에 있어?"
answer = chain.invoke({"info": info_str, "question": question})
print("답변:", answer)
# Out:
# 답변: 사과는 하나는 화면 오른쪽 중간에 있고, 다른 하나는 왼쪽 아래쪽에 있습니다.

# %%
question = "지금 보이는 사과의 위치를 사람을 기준으로 이야기해줘"
answer = chain.invoke({"info": info_str, "question": question})
print("답변:", answer)
# Out:
# 답변: 사람을 기준으로 볼 때, 위치 [255, 97]에서 [987, 795]까지의 바운딩박스 내에 사과 두 개가 있습니다. 첫 번째 사과는 사람보다 오른쪽에 있으며, 위치 [850, 374]에서 [967, 476]까지의 범위에 있고, 두 번째 사과는 왼쪽에 있으며, 위치 [265, 428]에서 [377, 537]까지의 범위에 있습니다.
